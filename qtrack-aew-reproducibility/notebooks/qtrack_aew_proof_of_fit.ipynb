# %% [markdown]
# # QTrack AEW proof-of-fit notebook
# This notebook is a compact guide to the repository workflow. The lightweight cells validate the synthetic input contract; the official QTrack run should be executed in an environment with QTrack installed and data-download access.

# %%
from pathlib import Path
import sys
sys.path.insert(0, str(Path('..') / 'scripts'))
from make_synthetic_winds import build_dataset
from check_input_contract import validate_dataset
ds = build_dataset(days=10)
validate_dataset(ds)

# %% [markdown]
# ## Official reproduction
# From the repository root, run:
# ```bash
# python scripts/run_qtrack_demo.py --case era5_2010_10day --jobs 2
# ```
# Then summarize and visualize the post-processed tracks using the provided scripts.
